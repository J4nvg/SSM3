# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import networkx as nx
import random
import heapq
import collections
from collections import deque

# %% [markdown]
# ### All the simulation uses hours and kilometers

# %%
ARRIVAL_RATE = np.array([314.2, 162.4, 138.6, 148.8, 273.2, 1118.8, 2773.8, 4036.2, 4237.4, 3277.0, 2843.0, 2876.4, 3143.0, 3277.8, 3546.2, 4335.0, 4945.4, 4525.8, 2847.8, 1828.0, 1378.4, 1271.2, 1171.2, 767.6])
INCIDENT_RATE = np.array([0.1935483870967742, 0.25806451612903225, 0.2903225806451613, 0.1935483870967742, 0.06451612903225806, 0.967741935483871, 32.16129032258065, 131.03225806451613, 157.2258064516129, 48.32258064516129, 8.451612903225806, 6.258064516129032, 8.161290322580646, 10.290322580645162, 19.0, 65.7741935483871, 157.41935483870967, 163.3548387096774, 36.54838709677419, 3.7096774193548385, 1.2258064516129032, 0.8709677419354839, 0.5806451612903226, 0.41935483870967744])
INCIDENT_DURATION_PARAMS = (1.2294425495153518, 0.09878316410683122, 5.082687545787541)
# INCIDENT_DURATION_PARAMS = ()

incident_duration_dist = stats.lognorm(*INCIDENT_DURATION_PARAMS)

MEAN_ACCIDENT_DURATION = 1

# %%
#Sampling arrival times of cars to network
def lambdat(lambda_t, t : np.array):
    lambdat = []
    for time in t:
        lambdat.append(lambda_t[int(np.floor(time))])
    return lambdat

def arrival_times(lam): #Taken from lecture notes
    max_T = 24
    arrival_times = collections.deque()
    exp_dist = stats.expon(scale = 1/lam)
    t = exp_dist.rvs()
    while t < max_T:
        arrival_times.append(t)
        t += exp_dist.rvs()
    
    return np.asarray(arrival_times)

# %%
class FES:
    def __init__(self):
        self.events = []

    def add(self, event):
        heapq.heappush(self.events, event)
    
    def next(self):
        return heapq.heappop(self.events)
    
    def isEmpty(self):
        return len(self.events) == 0
    
    def __repr__(self):
        string = ''
        sorted_events = sorted(self.events)
        for event in sorted_events:
            string += f'{event}\n'
        return string

# %%
class Queue:
    def __init__(self, road):
        self.road = road
        self.cars = []

    def add(self, car, time):
        heapq.heappush(self.cars, car)
        car.enter_queue(time)

    def add_list(self, list, time):
        for car in list:
            heapq.heappush(self.cars, car)
            car.enter_queue(time)   

    def next(self):
        return heapq.heappop(self.cars)
    
    def first(self):
        return heapq.nsmallest(1, self.cars)
    
    def isEmpty(self):
        return len(self.cars) == 0
    
    def __repr__(self):
        string = ''
        sorted_cars = sorted(self.cars)
        for car in sorted_cars:
            string += f'{car}\n'
        return string

# %%
class Event:
    TYPE = ['New car', 'Car departure', 'Accident', 'Accident end', 'left queue']
    def __init__(self, typ:int, time, car = None, road = None, duration = None):
        #types:
            #0 : Arrival of car to the network
            #1 : Car leaves current road and goes on to the next
            #2 : Accident in road
            #3 : End of accident
            #4 : Departure of car from queue of accident
        self.type = typ
        self.time = time
        self.road = road
        #Only for type 2 events bc needed for tow trucks
        self.duration = duration

        if typ == 0:
            car = Car(time_entrance = time)
    
        self.car = car
        
    def __str__(self):
        if self.type == 0:
            return f'{self.TYPE[self.type]} from {self.car.origin} to {self.car.destination} at {self.time}'
        if self.type == 1:
            return f'{self.TYPE[self.type]} of {self.car} at {self.time}h'
        if self.type == 2:
            return f'{self.TYPE[self.type]} at {self.road} at {self.time}h'
        if self.type == 3:
            return f'{self.TYPE[self.type]} at {self.road} at {self.time}h'
        if self.type == 4:
            return f'{self.car} {self.TYPE[self.type]} at {self.road} at {self.time}h'

    def __lt__(self, other):
        return self.time < other.time
    
    def new_time(self, new_time):
        self.time = new_time

# %%
class Car:
    VELOCITIES = [100, 80]
    VELOCITIES_P = [0.9, 0.1]
    def __init__(self, time_entrance, origin = None, destination = None):
        #Origin and destination
        origin, destination = np.random.choice(JUNCTIONS, 2, replace = False)
        
        self.origin = origin
        self.destination = destination

        #path to follow
        self.path = nx.shortest_path(Graph, self.origin, self.destination, weight = 'length')

        #Velocity
        self.velocity = np.random.choice(self.VELOCITIES, p=self.VELOCITIES_P)

        #Variable to keep track how far into the path we are (to simplify scheduling events)
        #Int between 0 and len(path) - 1 that indicates in which edge we are, starting at 0
        #Essentially, how many edges has it travelled so far
        self.progress = 0
        
        #Give it nav with 10% chance
        self.has_nav = np.random.choice([True, False], p=[0.1,0.9])
        self.changed_route = []

        #Time entrance
        self.time = time_entrance

        #Schedule next event and store it as attribute
        self.next_event = self.schedule_event_exit()


    def __str__(self):
        return f'Vehicle travelling from {self.origin} to {self.destination} at {self.velocity} km/h, atm at {self.path[self.progress]}'
    

    def custom_weight(self,u,v,data):
        """
        :param u: std for accepting function as weight, node 1
        :param v:  std for accepting function as weight, node 2
        :param data: std for accepting function as weight, edge
        :return: time_to_travel + delay
        """
        length = data['length']
        time_to_travel = (length / (self.velocity /3.6)) / 3600 #Mean of normal dist
        if Graph.edges[(u,v)]['accident']:   
            delay = MEAN_ACCIDENT_DURATION
        else:
            delay = 0
        return time_to_travel + delay
    
    def calc_time_to_travel(self,length):
        """
        :param length: edge length
        :return: returns time to traverse length based on normal speed
        """
        mean = length / (self.velocity /3.6) #seconds
        std = mean / 20
        time_to_travel = np.random.normal(loc = mean, scale = std) / 3600 #back to hours
        return time_to_travel

    def schedule_event_exit(self):
        #Remove car from list of cars in previous edge
        if self.progress > 0:
            #Edges can be expressed in two directions, account for it
            edge = (self.path[self.progress - 1], self.path[self.progress])
            # if edge in DIC_EDGES.keys():
            #     DIC_EDGES[edge].remove(self)
            # else:
            #     DIC_EDGES[edge[::-1]].remove(self)
            DIC_EDGES[edge].remove(self)


        if self.progress < len(self.path) - 1:
            # Get the current and next node on the original path
            current_node = self.path[self.progress]
            next_node = self.path[self.progress + 1]
            edge = Graph.edges[(current_node, next_node)]

            # Check for accident on the current edge and if nav is enabled
            # No need to check for accident, just check if navigation (there may be accidents later that makes us recompute)
            if self.has_nav:
                # print("Updating path")
                new_path = nx.shortest_path(Graph, current_node, self.destination, weight=self.custom_weight)

                if new_path != self.path[self.progress:]:
                    print("Found a quicker route")
                    # print(f"Prev path = {[Graph.nodes[node]['name'] for node in self.path]}")
                    # print(f"New path = {[Graph.nodes[node]['name'] for node in new_path]}")

                    #I commented this out bc append is not efficient
                    # self.changed_route.append((self.path, new_path))

                    # Preserve the already traversed portion
                    prefix = self.path[:self.progress]

                    updated_path = prefix + new_path
                    self.path = updated_path
                    # print(f"Updated path: {[Graph.nodes[node]['name'] for node in self.path]}")

                    # Update next_node based on the new path
                    next_node = self.path[self.progress + 1]
                    edge = Graph.edges[(current_node, next_node)]
                    length = edge['length']
                    # Sample travel time along the new edge (including accident delay)
                    
                    #I think no need to add accident duration bc i account for this in my code alr and a accident can happen before scheduling this
                    # time_to_travel = self.calc_time_to_travel(length) + edge['accident_duration']
                    time_to_travel = self.calc_time_to_travel(length)
                else:
                    # No change in path (fallback scenario)
                    length = edge['length']
                    time_to_travel = self.calc_time_to_travel(length)
            else:
                # Normal travel (no accident on the edge)
                length = edge['length']
                time_to_travel = self.calc_time_to_travel(length)

            new_time = self.time + time_to_travel
            # Schedule next event and update car's progress and time
            self.next_event = Event(1, new_time, car=self)
            self.increase_progress()
            self.increase_time(new_time)

            #Add car to list of cars in the new edge
            edge = (self.path[self.progress - 1], self.path[self.progress])
            # if edge in DIC_EDGES.keys():
            #     DIC_EDGES[edge].append(self)
            # else:
            #     DIC_EDGES[edge[::-1]].append(self)
            DIC_EDGES[edge].append(self)

            return self.next_event


    # def schedule_event_exit(self):

    #     #Remove car from list of cars in previous edge
    #     if self.progress > 0:
    #         #Edges can be expressed in two directions, account for it
    #         edge = (self.path[self.progress - 1], self.path[self.progress])
    #         # if edge in DIC_EDGES.keys():
    #         #     DIC_EDGES[edge].remove(self)
    #         # else:
    #         #     DIC_EDGES[edge[::-1]].remove(self)
    #         DIC_EDGES[edge].remove(self)


    #     if  self.progress < len(self.path) - 1: 
    #         #find next edge to travel through and its length
    #         edge = Graph.edges[(self.path[self.progress], self.path[self.progress + 1])]
    #         length = edge['length']

    #         #Sample travel time of edge
    #         mean = length / (self.velocity /3.6) #seconds
    #         std = mean / 20
    #         time_to_travel = np.random.normal(loc = mean, scale = std) / 3600 #back to hours

    #         new_time = self.time + time_to_travel

    #         #Store event and increase progress
    #         self.next_event = Event(1 , new_time, car=self)
    #         self.increase_progress()
    #         self.increase_time(new_time)

    #         #Add car to list of cars in the new edge
    #         edge = (self.path[self.progress - 1], self.path[self.progress])
    #         # if edge in DIC_EDGES.keys():
    #         #     DIC_EDGES[edge].append(self)
    #         # else:
    #         #     DIC_EDGES[edge[::-1]].append(self)
    #         DIC_EDGES[edge].append(self)

    #         return self.next_event
        
    #     # if self.progress == len(self.path) - 1:
    #     #     print('Car has reached its destination')
    #     #     self.travel_time = self.next_event.time
    
    def increase_progress(self):
        self.progress += 1

    def increase_time(self, new_time):
        self.time = new_time

    def __lt__(self, other):
        return self.time < other.time
    
    def enter_queue(self, time):
        #store time at which the car entered the queue
        self.time_enter = time

    def exit_queue(self, time_exit):
        #Update time of car when it left the queue
        self.time += time_exit - self.time_enter

        #Update time of event leaving road
        self.next_event.new_time(self.time)

# %%
class TowTruck:
    def __init__(self, origin, name=f"Truck {random.randint(0,100)}"):
        self.origin = origin
        self.isHome = True
        self.velocity = 80
        self.progress = 0
        self.time = 0
        self.going_home = False
        self.name = name
        self.next_event = None
    def __str__(self):
        at = self.path[self.progress]
        return f"Tow Truck travelling from {Graph.nodes[self.origin]['name']} to {Graph.edges[self.destination_road]} at {self.velocity} km/h, atm at {Graph.nodes[at]['name']}"

    def calc_time_to_travel(self,length):
        """
        :param length: edge length
        :return: returns time to traverse length based on normal speed
        """
        mean = length / (self.velocity /3.6) #seconds
        std = mean / 20
        time_to_travel = np.random.normal(loc = mean, scale = std) / 3600 #back to hours
        return time_to_travel

    def new_destination(self, destination_road, destination, current_time, distance_from_junction):
        if self.isHome:
            #Lets make destination = first item in destination road
            if self.origin == destination:
                self.destination = destination_road[1]
            else:
                 self.destination = destination
            self.destination_road = destination_road
            self.add_d = distance_from_junction
            self.path = nx.shortest_path(Graph, self.origin, self.destination, weight = 'length')
            self.isHome = False
            self.going_home = False
            self.time = current_time
            new_event = self.schedule_event_exit()
            
            return new_event
        else:
            print("Not able to set new destination, vehicle still on the road.")

    def schedule_event_exit(self):
        #Car is travelling and did not reach destination yet

        if  self.progress < len(self.path) - 1:
            # Can go on emergency lane so doesn't care for traffic jam
            current_node = self.path[self.progress]
            next_node = self.path[self.progress + 1]
            print(f"{self.name} Now going from {Graph.nodes[current_node]['name']} to {Graph.nodes[next_node]['name']} at time {self.time}\n")

            length = Graph.edges[(current_node,next_node)]['length']
            time_to_travel = self.calc_time_to_travel(length)

            new_time = self.time + time_to_travel
            print(f"{self.name} reaching {Graph.nodes[next_node]['name']} at time {new_time}\n")
            #Store event and increase progress
            self.next_event = Event(1 , new_time, car=self)
            self.increase_progress()
            self.increase_time(new_time)
            
            if self.going_home:
                print('On its way home')

            return self.next_event

        # Car reached destination, and is not going home
        elif (not(self.going_home)) and (self.progress == len(self.path) - 1):
            if self.origin == self.destination:
                print("TRIGGERED GORINCHEM ISSUE")
                self.progress =0
                # reached destination, Drive additional length to incident:
                self.time +=  self.calc_time_to_travel(self.add_d)
                print(f"Increased time {self.name} time to {self.time}")
                solving_event = Event(3, self.time, road = self.destination_road)
                print(f" {self.name} Solved event time {self.time}")
                # Calculate how long it takes to get to the other side of the road, i.e. next junction
                tot_road_length = nx.path_weight(Graph, self.destination_road,weight='length')
                # 'Drive' to other side
                self.time += self.calc_time_to_travel(tot_road_length-self.add_d)
                print(f" Arrived at opposite side of the road {self.time}")
                # Calculate new path from other side of the road
                self.path = [self.destination_road[1],self.destination_road[0]]
                print(f" Path to get back:{Graph.nodes[self.destination_road[1]]['name']} -> {Graph.nodes[self.destination_road[0]]['name']} {self.time}")
                length = Graph.edges[tuple(self.path)]['length']
                time_to_travel = self.calc_time_to_travel(length)
                new_time = self.time + time_to_travel
                print(f" Arrived back at origin base {new_time}")
                self.progress = len(self.path)-1
                self.increase_time(new_time)
                print(f" updated time to {self.time}")
                self.isHome = True
                self.going_home = False
                print(f"Now sending event back to event handler")
                return ['Truck back', solving_event]


            # reached destination, Drive additional length to incident:
            self.time +=  self.calc_time_to_travel(self.add_d)
            solving_event = Event(3, self.time, road = self.destination_road)
            # Calculate how long it takes to get to the other side of the road, i.e. next junction
            tot_road_length = nx.path_weight(Graph, self.destination_road,weight='length')
            # 'Drive' to other side
            self.time += self.calc_time_to_travel(tot_road_length-self.add_d)
            # Calculate new path from other side of the road

            self.path = nx.shortest_path(Graph, self.destination_road[1], self.origin, weight = 'length')

            # Reset progress
            print(f"New path {[Graph.nodes[nodes]['name'] for nodes in self.path]}")
            self.progress = 0

            # edge = Graph.edges[(self.destination, self.path[1])]
            print('Heading home')
            if len(self.path) > 1:
                print("##### Flag 0 #####")
                length = Graph.edges[(self.destination_road[1], self.path[1])]['length']

                time_to_travel = self.calc_time_to_travel(length)
                new_time = self.time + time_to_travel

                self.increase_progress()
                self.increase_time(new_time)
                self.next_event = Event(1, new_time, car=self)
                self.going_home = True
                
                return [self.next_event, solving_event]
            else:
                #Never triggered, Alr at home
                print("##### Flag 1 #####")
                self.isHome = True
                self.going_home = False
                return ['Truck back', solving_event]
        # Car is going home, and reached destination, thus reached home
        elif (self.going_home) and (self.progress == len(self.path) - 1):
            self.isHome = True
            self.going_home = False
            return 'Truck back'

    def increase_progress(self):
        self.progress += 1

    def increase_time(self, new_time):
        self.time = new_time

# %%
class IncidentSolvers:
    def __init__(self,K_trucks, origin ='2752332143'):
        self.origin = origin
        self.K_trucks = K_trucks
        self.trucks = []
        self.available = deque()
        self.unavailable = deque()
        for i in range(K_trucks):
            truck = TowTruck(origin=origin)
            truck.name = f"Truck {i}"

            self.trucks.append(truck)
            self.available.append(truck)

    def truck_returned(self, truck):
        if truck in self.unavailable:
            self.unavailable.remove(truck)

        self.available.append(truck)
        truck.progress = 0
        truck.isHome = True
        truck.going_home = False
        truck.path = None
        print(f"Truck {truck.name} returned to base at time {truck.time}")
        print("Trucks available after return:",len(self.available),'\n')


    def send_truck(self, destination_road, incident_duration, current_time,location):
        print(f"trying to send a truck, \n \
        amount trucks available: {len(self.available)} \n trucks available: {[truck.name for truck in self.available]}\n")
        if len(self.available) > 0:
            truck = self.available.pop()
            # Check if truck can reach in time
            destination = destination_road[0]
            path = nx.shortest_path(Graph, self.origin, destination, weight='length')
            length = nx.path_weight(Graph, path,weight='length')
            length_additional = location * nx.path_weight(Graph, destination_road,weight='length')
            time_to_travel = truck.calc_time_to_travel(length + length_additional)


            if time_to_travel> incident_duration:
                print("Takes too long to reach incident location\n")
                self.available.append(truck)
                return
            else:
                # Send the truck to the incident.
                print(f"sending truck {truck.name} to {Graph.nodes[destination]['name']} at time {current_time}\n")
                print(f"location {location*100}% from {Graph.nodes[destination_road[0]]['name']} to {Graph.nodes[destination_road[1]]['name']} ")
                print(f"Incident at {length_additional} from {Graph.nodes[destination]['name']}, total_length = {nx.path_weight(Graph, destination_road,weight='length')}")
                print(f"Reaching {Graph.nodes[destination]['name']} at {current_time+ truck.calc_time_to_travel(length)} ")
                reaching_time = current_time + time_to_travel
                print(f"Reaching incident at {reaching_time} incident should be solved atmost {current_time + incident_duration}\n")
                event_truck = truck.new_destination(destination_road,destination, current_time, distance_from_junction=length_additional)
                self.unavailable.append(truck)
                return event_truck

        else:
            print('No trucks available sry')

# %%
Graph = nx.read_gml('./data/networkAssignment.gml')
Graph = Graph.to_directed()
JUNCTIONS = list(Graph.nodes)
DIC_EDGES = {}
#Dictionary that keeps track on when the last accident ends in a road before another one can take place
DIC_ACCIDENTS = {}
for edge in Graph.edges:
    DIC_EDGES[edge] = []
    DIC_ACCIDENTS[edge] = 0
    #Associate departure from queue distribution to each edge based on number of lanes
    rate = 0.2/(60 * Graph.edges[edge]['lanes'])
    Graph.edges[edge]['DepDist'] = stats.expon(scale = rate)

    Graph.edges[edge]['accident'] = False
    Graph.edges[edge]['queue'] = False
    # Graph.edges[edge]['accident_duration'] = 0

# %%
#Using a thining approach to get arrival times
max_lambda = np.max(ARRIVAL_RATE) + 1
all_arrivals = arrival_times(max_lambda)

uniform_dist = stats.uniform(0,1)
u_rvs = uniform_dist.rvs(len(all_arrivals))
accept_filter = u_rvs * max_lambda < lambdat(ARRIVAL_RATE, all_arrivals)

accepted_arrivals = all_arrivals[accept_filter]

# %%
#Using a thining approach to get accident times
max_lambda = np.max(INCIDENT_RATE) + 1
all_accidents = arrival_times(max_lambda)

uniform_dist = stats.uniform(0,1)
u_rvs = uniform_dist.rvs(len(all_accidents))
accept_filter = u_rvs * max_lambda < lambdat(INCIDENT_RATE, all_accidents)

accepted_accidents = all_accidents[accept_filter]

# %%
incident_solvers = IncidentSolvers(2)

# %%
#Simulation (can be turned into an object later)
LIST_CARS = []
fes = FES()
# for arrival in accepted_arrivals:
#     #Two events associated with each arrival
#     arrival_event = Event(0, arrival)
#     fes.add(arrival_event)

for accident in accepted_accidents:
    affected_road = list(Graph.edges)[np.random.choice(len(Graph.edges))]
    if DIC_ACCIDENTS[affected_road] < accident:
        duration = incident_duration_dist.rvs()/60
        time_end = accident + duration
        accident_event = Event(2, accident, road=affected_road, duration=duration)
        end_accident = Event(3, time_end, road=affected_road)

        fes.add(accident_event)
        fes.add(end_accident)
        DIC_ACCIDENTS[affected_road] = time_end

#Queue for accidents setup
Queues = {}
for edge in DIC_EDGES.keys():
    Queues[edge] = Queue(edge)

# %%
# road = list(DIC_EDGES.keys())[0]
# accident = Event(2, 0.5, road=road)
# end_accident = Event(3, 0.6, road =road)
# fes.add(accident)
# fes.add(end_accident)
# road = road[::-1]
# accident = Event(2, 0.5, road=road)
# end_accident = Event(3, 0.6, road =road)
# fes.add(accident)
# fes.add(end_accident)

# %%
t = 0 #current time
while t < 24.0:
    event = fes.next()
    t = event.time

    #Car joins network
    if event.type == 0:
        car_travel_event = event.car.next_event
        fes.add(car_travel_event)
        LIST_CARS.append(event.car)

    #Car leaves road
    if event.type == 1:
        next_travel_event_car = event.car.schedule_event_exit()
        if type(next_travel_event_car) == Event: #If the car has arrived to its destination it wont return an event object
            fes.add(next_travel_event_car)

        #when a tow truck arrives to the accident it wants to solve, it will return two events
        if type(next_travel_event_car) == list:
            #Event for fixing the accident
            fes.add(next_travel_event_car[1])
            print(f'Tow truck solved accident {t} truck time:{event.car.time}')

            print(next_travel_event_car)
            #Event for heading back
            if type(next_travel_event_car[0]) == Event:
                fes.add(next_travel_event_car[0])
            #it may alr be at home
            elif next_travel_event_car[0] == 'Truck back':
                incident_solvers.truck_returned(event.car)
                print(f'Tow truck back {t} truck time:{event.car.time}')

        if next_travel_event_car == 'Truck back':
            incident_solvers.truck_returned(event.car)
            print(f'Tow truck back {t} truck time:{event.car.time}')
         # else:
            # print(event.car)

    #Start accident
    if event.type == 2:
        road = event.road
        #choose random cars affected:
            #List comprehension is inefficient af here
            # cars_not_in_queue = [car for car in DIC_EDGES[road] if car not in Queues[road].cars]
        cars_not_in_queue = list(set(DIC_EDGES[road]) - set(Queues[road].cars))
        if len(cars_not_in_queue) != 0:


            amount_cars_affected = np.random.randint(len(cars_not_in_queue))
            cars_affected = np.random.choice(cars_not_in_queue, amount_cars_affected, replace=False)


            #####Consider sorting list of cars before chooisng which ones are affected


            Queues[road].add_list(cars_affected, event.time)
        Graph.edges[road]['accident'] = True
        #Send tow truck
        # print("This road:",road)

        # Location on the road
        # Trying to keep it simple for debug purpose
        # Loc * Length / velocity will be the additional time it takes
        loc = stats.uniform(0, 1).rvs()

        first_event_truck = incident_solvers.send_truck(road, event.duration, event.time,location=loc)
        print(f'1330 {first_event_truck}, {type(first_event_truck)}')
        #If no trucks are available first_event_truck will be empty
        if type(first_event_truck) == Event:
            fes.add(first_event_truck)
            print(f'Tow truck on its way {t}')
        elif type(first_event_truck) == list:
            fes.add(first_event_truck[1])
            print(f'Tow truck on its way {t}')
        else:
            print(f'Tow trucks all busy  {t}')

    #End accident
    if event.type == 3:
        road = event.road
        #A tow truck may have ended he accident before so there could be two events for ending it, hence only do it if there is still an accident
        if Graph.edges[road]['accident']:
            #1 minute until first car leaves the queue 
            if not(Queues[road].isEmpty()) and not(Graph.edges[road]['queue']):
                # print(f'First event departure {Queues[road].isEmpty()}', road)
                first_departure_event = Event(4, event.time + 1/60, road=road)
                # print(first_departure_event)
                fes.add(first_departure_event)
                Graph.edges[road]['queue'] = True
            Graph.edges[road]['accident'] = False   
        # print(t)
        else:
            print(f'Accident already solved {t}')
    
    #Departure from road
    if event.type == 4:
        # print(event)
        road = event.road
        time = event.time
        #Remove car from queue
        # print(len(Queues[road].cars), event.road)
        car = Queues[road].next()

        #Modify time to arrival of next node in path
        car.exit_queue(time)

        if not(Queues[road].isEmpty()):
            #Next departure event
            next_event_time = time + Graph.edges[road]['DepDist'].rvs()
            
            next_event = Event(4, next_event_time, road=road)
            # print(next_event)
            fes.add(next_event)
        else:
            Graph.edges[road]['queue'] = False
# Out:
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 0', 'Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  1.5138111279586313
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 0', 'Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  1.8592963994667089
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 0', 'Truck 1']
#
# sending truck Truck 1 to Knooppunt Deil at time 6.004017816346744
#
# location 52.969694720701746% from Knooppunt Deil to Knooppunt Everdingen
# Incident at 5827.725813171606 from Knooppunt Deil, total_length = 11002.0
# Reaching Knooppunt Deil at 6.195553112784671
# Reaching incident at 6.2465739949717936 incident should be solved atmost 6.492845421397434
#
# Truck 1 Now going from Knooppunt Gorinchem to Knooppunt Deil at time 6.004017816346744
#
# Truck 1 reaching Knooppunt Deil at time 6.209242776970832
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Everdingen->Knooppunt Deil', 'highway': 'motorway_link', 'length': 11002.0, 'lanes': 5, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9789340>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Deil at 6.209242776970832h, <class '__main__.Event'>
# Tow truck on its way 6.004017816346744
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Everdingen at time 6.082617504479266
#
# location 29.753277058653016% from Knooppunt Everdingen to Knooppunt Oudenrijn
# Incident at 1613.8177476613396 from Knooppunt Everdingen, total_length = 5424.0
# Reaching Knooppunt Everdingen at 6.306376615618907
# Reaching incident at 6.334014027379749 incident should be solved atmost 6.58279658157134
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Everdingen at time 6.082617504479266
#
# Truck 0 reaching Knooppunt Everdingen at time 6.310011681853966
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Everdingen->Knooppunt Oudenrijn', 'highway': 'motorway_link', 'length': 5424.0, 'lanes': 5, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9788EC0>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Everdingen at 6.310011681853966h, <class '__main__.Event'>
# Tow truck on its way 6.082617504479266
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.146698011285442
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.154322463530082
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.15620246436498
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.2071859443782005
# New path ['Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 6.209242776970832 truck time:6.590981819067129
# [<__main__.Event object at 0x00000177D97DD970>, <__main__.Event object at 0x00000177D97DD9A0>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.223804885713578
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.225679639443026
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.240620570925888
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.250722663798559
# New path ['Knooppunt Oudenrijn', 'Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 6.310011681853966 truck time:6.443116242258194
# [<__main__.Event object at 0x00000177D97DC0B0>, <__main__.Event object at 0x00000177D97DD8B0>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.418081289639791
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.435066257044272
# Truck 0 Now going from Knooppunt Everdingen to Knooppunt Gorinchem at time 6.443116242258194
#
# Truck 0 reaching Knooppunt Gorinchem at time 6.69384635808225
#
# On its way home
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.44865408478999
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.465216463561642
# Accident already solved 6.492845421397434
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.499275059215497
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.544968626927328
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.551892749781716
# Accident already solved 6.58279658157134
# Truck Truck 1 returned to base at time 6.590981819067129
# Trucks available after return: 1
#
# Tow truck back 6.590981819067129 truck time:6.590981819067129
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.601844454412703
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.655829858663635
# Truck Truck 0 returned to base at time 6.69384635808225
# Trucks available after return: 2
#
# Tow truck back 6.69384635808225 truck time:6.69384635808225
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.771544241716982
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.784775649262626
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.805850419249807
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.8709573839687685
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.890492074837498
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.901148948253935
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.939693674816975
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# sending truck Truck 0 to Knooppunt Zonzeel at time 7.0056475215618645
#
# location 78.7833997954376% from Knooppunt Zonzeel to Knooppunt Princeville
# Incident at 4974.38386308393 from Knooppunt Zonzeel, total_length = 6314.0
# Reaching Knooppunt Zonzeel at 7.304839620229657
# Reaching incident at 7.370367540997554 incident should be solved atmost 7.50055124975327
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Hooipolder at time 7.0056475215618645
#
# Truck 0 reaching Knooppunt Hooipolder at time 7.178225115744026
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Zonzeel->Knooppunt Princeville', 'highway': 'motorway_link', 'length': 6314.0, 'lanes': 4, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D97767E0>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Hooipolder at 7.178225115744026h, <class '__main__.Event'>
# Tow truck on its way 7.0056475215618645
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.006024395416076
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.037642294557464
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.041316397807459
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.0515916856001715
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.056454427216477
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# sending truck Truck 1 to Knooppunt Gorinchem at time 7.073499320641144
#
# location 32.853589471206014% from Knooppunt Gorinchem to Knooppunt Everdingen
# Incident at 5848.267461769382 from Knooppunt Gorinchem, total_length = 17801.0
# Reaching Knooppunt Gorinchem at 7.073499320641144
# Reaching incident at 7.145925539884407 incident should be solved atmost 7.449820951601718
#
# Truck 1 Now going from Knooppunt Gorinchem to Knooppunt Everdingen at time 7.073499320641144
#
# Truck 1 reaching Knooppunt Everdingen at time 7.283405801206579
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gorinchem->Knooppunt Everdingen', 'highway': 'motorway_link', 'length': 17801.0, 'lanes': 2, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9775130>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Everdingen at 7.283405801206579h, <class '__main__.Event'>
# Tow truck on its way 7.073499320641144
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.102110561642984
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.109639369128597
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.119034641209518
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.126679368616355
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.127140264956144
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.137661334163886
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.172035507605427
# Truck 0 Now going from Knooppunt Hooipolder to Knooppunt Zonzeel at time 7.178225115744026
#
# Truck 0 reaching Knooppunt Zonzeel at time 7.301301560625259
#
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.188465419807032
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.1903811339426245
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.199060414960358
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.201041741367932
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.2077721850150756
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.21871153055379
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.241036112292519
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.245455281276607
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.256588174505269
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.2586503834346265
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.269435499210821
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.270366240142071
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.275881140810986
# New path ['Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 7.283405801206579 truck time:7.734741895937719
# [<__main__.Event object at 0x00000177D97DF590>, <__main__.Event object at 0x00000177D9727560>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.287088668997569
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.294223589295018
# New path ['Knooppunt Princeville', 'Knooppunt Zonzeel', 'Knooppunt Hooipolder', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 7.301301560625259 truck time:7.459649287039926
# [<__main__.Event object at 0x00000177D97DF710>, <__main__.Event object at 0x00000177D97DF440>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.3112451577583295
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.312797425519676
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.334385692730639
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.337105344866436
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.345738538847031
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.348182901802336
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.359834375948757
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.3670457472976985
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.379694460296641
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.380348255262488
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.3993143425112216
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.399540586732079
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.403684403168727
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.421604253622712
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.42526792656502
# Accident already solved 7.449820951601718
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.4558544009350465
# Truck 0 Now going from Knooppunt Zonzeel to Knooppunt Hooipolder at time 7.459649287039926
#
# Truck 0 reaching Knooppunt Hooipolder at time 7.580835609529148
#
# On its way home
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.45972478905429
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.461379473561141
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.4683352735524196
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.469168335358602
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.488836741486618
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.500412172828165
# Accident already solved 7.50055124975327
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.504189064078733
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.50858931351668
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.53044395863368
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.531043016679314
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.533943019413837
# Truck 0 Now going from Knooppunt Hooipolder to Knooppunt Gorinchem at time 7.580835609529148
#
# Truck 0 reaching Knooppunt Gorinchem at time 7.736045490346042
#
# On its way home
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.582476225781556
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.582892477246419
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.586727750889211
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.590345464268041
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.605951313127824
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.610989637175717
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.618686786781597
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.619606122765836
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.623649843953696
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.636352969673174
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.656932645494454
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.660296811982535
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.692932306051536
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.709028180070982
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.709042582593333
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.709181585853566
# Truck Truck 1 returned to base at time 7.734741895937719
# Trucks available after return: 1
#
# Tow truck back 7.734741895937719 truck time:7.734741895937719
# Truck Truck 0 returned to base at time 7.736045490346042
# Trucks available after return: 2
#
# Tow truck back 7.736045490346042 truck time:7.736045490346042
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# sending truck Truck 0 to Knooppunt Gorinchem at time 7.7546554491521675
#
# location 16.55248948898761% from Knooppunt Gorinchem to Knooppunt Deil
# Incident at 2588.1472564981027 from Knooppunt Gorinchem, total_length = 15636.0
# Reaching Knooppunt Gorinchem at 7.7546554491521675
# Reaching incident at 7.788674575209435 incident should be solved atmost 7.793226646392931
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Deil at time 7.7546554491521675
#
# Truck 0 reaching Knooppunt Deil at time 7.955510995587299
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gorinchem->Knooppunt Deil', 'highway': 'motorway_link', 'length': 15636.0, 'lanes': 2, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9776600>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Deil at 7.955510995587299h, <class '__main__.Event'>
# Tow truck on its way 7.7546554491521675
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.76599881740795
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.767945039526054
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.774125643815724
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.7769645471524935
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.792022683886191
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.794724804391981
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# sending truck Truck 1 to Knooppunt Terbregseplein at time 7.795506983865858
#
# location 53.43104175287383% from Knooppunt Terbregseplein to Knooppunt Ridderkerk
# Incident at 1296.237072924719 from Knooppunt Terbregseplein, total_length = 2426.0
# Reaching Knooppunt Terbregseplein at 8.065654508228448
# Reaching incident at 8.091049577612797 incident should be solved atmost 8.322277990918092
#
# Truck 1 Now going from Knooppunt Gorinchem to Knooppunt Ridderkerk at time 7.795506983865858
#
# Truck 1 reaching Knooppunt Ridderkerk at time 8.038121228991319
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Terbregseplein->Knooppunt Ridderkerk', 'highway': 'motorway_link', 'length': 2426.0, 'lanes': 3, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9777A10>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Ridderkerk at 8.038121228991319h, <class '__main__.Event'>
# Tow truck on its way 7.795506983865858
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.820773054446531
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.845481466427146
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.845991693541394
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.851024340468482
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.867291197275778
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.880158201661396
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.885043155961309
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.885597246187273
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.893096389049799
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.906015853759739
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.91269971671954
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.950468347121306
# New path ['Knooppunt Deil', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 7.955510995587299 truck time:8.342804615961517
# [<__main__.Event object at 0x00000177D9834F80>, <__main__.Event object at 0x00000177D96FFCE0>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.969526802494902
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.97136401254393
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.982384475813156
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.984253796875804
# Accident already solved 7.988615464796383
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.000477513462975
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.003355873400192
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.005608054284496
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.010212790152146
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.010233144421765
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.010870957682918
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.017812502942743
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.021732454355085
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.035522861376348
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.036918338605142
# Truck 1 Now going from Knooppunt Ridderkerk to Knooppunt Terbregseplein at time 8.038121228991319
#
# Truck 1 reaching Knooppunt Terbregseplein at time 8.066695229736137
#
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.05259975695987
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.064079542562427
# New path ['Knooppunt Ridderkerk', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 8.066695229736137 truck time:8.33429320830194
# [<__main__.Event object at 0x00000177D9835520>, <__main__.Event object at 0x00000177D9835580>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.091290402482281
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.101581104880953
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.113340550133271
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.125370865450178
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.133089024820256
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.165318974370704
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.173043570975286
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.174813897401375
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.180564139863106
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.181184020761135
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.182423417224156
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.183504137904933
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.185338382794981
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.193898609687242
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.19799120099987
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.203820662780695
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.209261172706958
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.252341919506064
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.255134035003293
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.255704999583784
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.279685194578322
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.285251757596958
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.287768370962377
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.29092136864174
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.29148803957527
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.30849252322607
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.311456503079034
# Accident already solved 8.322277990918092
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.328196124465155
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.33308609173079
# Truck Truck 1 returned to base at time 8.33429320830194
# Trucks available after return: 1
#
# Tow truck back 8.33429320830194 truck time:8.33429320830194
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.335295600729866
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# sending truck Truck 1 to Knooppunt Gorinchem at time 8.337106167185802
#
# location 86.34181446610012% from Knooppunt Gorinchem to Knooppunt Ridderkerk
# Incident at 16680.375136705883 from Knooppunt Gorinchem, total_length = 19319.0
# Reaching Knooppunt Gorinchem at 8.337106167185802
# Reaching incident at 8.53690376370998 incident should be solved atmost 8.590222433120614
#
# Truck 1 Now going from Knooppunt Gorinchem to Knooppunt Ridderkerk at time 8.337106167185802
#
# Truck 1 reaching Knooppunt Ridderkerk at time 8.58711498067792
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gorinchem->Knooppunt Ridderkerk', 'highway': 'motorway_link', 'length': 19319.0, 'lanes': 2, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9774D70>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Ridderkerk at 8.58711498067792h, <class '__main__.Event'>
# Tow truck on its way 8.337106167185802
# Truck Truck 0 returned to base at time 8.342804615961517
# Trucks available after return: 1
#
# Tow truck back 8.342804615961517 truck time:8.342804615961517
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.35289277133992
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.377389644147165
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.397170518342927
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.397455429046458
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.398514767826706
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.40100583512163
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.41303587739982
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.4167868860096
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.420000362849356
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.424725294358124
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Gorinchem at time 8.433341954795427
#
# location 65.79694345047062% from Knooppunt Gorinchem to Knooppunt Everdingen
# Incident at 11712.513903618275 from Knooppunt Gorinchem, total_length = 17801.0
# Reaching Knooppunt Gorinchem at 8.433341954795427
# Reaching incident at 8.569435583040967 incident should be solved atmost 8.607061965760915
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Everdingen at time 8.433341954795427
#
# Truck 0 reaching Knooppunt Everdingen at time 8.672183925288582
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gorinchem->Knooppunt Everdingen', 'highway': 'motorway_link', 'length': 17801.0, 'lanes': 2, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9775130>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Everdingen at 8.672183925288582h, <class '__main__.Event'>
# Tow truck on its way 8.433341954795427
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.436813572930898
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.44506264337585
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.452760415682496
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.498668211660688
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.516196944283207
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.517567234064856
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.529565243853934
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.53736134951823
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.56981454446274
# New path ['Knooppunt Ridderkerk', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 8.58711498067792 truck time:9.073650389306044
# [<__main__.Event object at 0x00000177D97DFC50>, <__main__.Event object at 0x00000177D95EF380>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.593308965589502
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.597656865267094
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.600375611227063
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.606584359091151
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.618138810126588
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.622033735343575
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.633463301842568
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.64183011423167
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.648392958894858
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.6629233047656
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.663603971078626
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.670660693973327
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.671217084050392
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.671659113211048
# New path ['Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 8.672183925288582 truck time:9.10709979234327
# ...
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.779785244336438
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.77997370334656
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.783537818070833
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.784936914523357
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.786320622288613
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.793934657711656
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.794069953340923
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.821333203664004
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.832108571098438
# Accident already solved 17.83923433182628
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.849382683940206
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.865195522383615
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.87134030434206
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.874702549794563
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.88573987708481
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.89152233389407
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.89845863781523
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.915909660199173
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.923868088975546
# Truck 0 Now going from Knooppunt Zonzeel to Knooppunt Hooipolder at time 17.928971117180414
#
# Truck 0 reaching Knooppunt Hooipolder at time 18.056600256129197
#
# On its way home
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.93235443462631
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.942241803937314
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.943854281752174
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.9672589104236
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.97253697943272
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.993034898964464
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.02951200722536
# Truck 0 Now going from Knooppunt Hooipolder to Knooppunt Gorinchem at time 18.056600256129197
#
# Truck 0 reaching Knooppunt Gorinchem at time 18.21316001894434
#
# On its way home
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.059978611007352
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.0615954602523
# Truck 1 Now going from Knooppunt Empel to Knooppunt Deil at time 18.10233207549193
#
# Truck 1 reaching Knooppunt Deil at time 18.260632919854054
#
# On its way home
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.13910947039492
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.14447708931259
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.152154862249038
# Truck Truck 0 returned to base at time 18.21316001894434
# Trucks available after return: 1
#
# Tow truck back 18.21316001894434 truck time:18.21316001894434
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.24516434874996
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.256630460043436
# Truck 1 Now going from Knooppunt Deil to Knooppunt Gorinchem at time 18.260632919854054
#
# Truck 1 reaching Knooppunt Gorinchem at time 18.460983130209172
#
# On its way home
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.278718317681292
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.36087567300222
# Truck Truck 1 returned to base at time 18.460983130209172
# Trucks available after return: 2
#
# Tow truck back 18.460983130209172 truck time:18.460983130209172
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 0', 'Truck 1']
#
# sending truck Truck 1 to Knooppunt Deil at time 18.557265518284392
#
# location 91.22775731383265% from Knooppunt Deil to Knooppunt Everdingen
# Incident at 10036.87785966787 from Knooppunt Deil, total_length = 11002.0
# Reaching Knooppunt Deil at 18.750439586725857
# Reaching incident at 18.89160188117529 incident should be solved atmost 18.998420198109535
#
# Truck 1 Now going from Knooppunt Gorinchem to Knooppunt Deil at time 18.557265518284392
#
# Truck 1 reaching Knooppunt Deil at time 18.763044193576658
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Everdingen->Knooppunt Deil', 'highway': 'motorway_link', 'length': 11002.0, 'lanes': 5, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9789340>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Deil at 18.763044193576658h, <class '__main__.Event'>
# Tow truck on its way 18.557265518284392
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.55974498579721
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.566041401749946
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Deil at time 18.58371961013269
#
# location 85.91203631307559% from Knooppunt Deil to Knooppunt Empel
# Incident at 10751.03222421828 from Knooppunt Deil, total_length = 12514.0
# Reaching Knooppunt Deil at 18.789210936384105
# Reaching incident at 18.91240354706714 incident should be solved atmost 19.17020372721908
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Deil at time 18.58371961013269
#
# Truck 0 reaching Knooppunt Deil at time 18.778155326112394
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Empel->Knooppunt Deil', 'highway': 'motorway_link', 'length': 12514.0, 'lanes': 4, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9789070>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Deil at 18.778155326112394h, <class '__main__.Event'>
# Tow truck on its way 18.58371961013269
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.615856602536685
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.617225361843893
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.6812559264964
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.709787077503613
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.71347387243589
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.71715170508816
# New path ['Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 18.763044193576658 truck time:19.120845814485378
# [<__main__.Event object at 0x00000177D97DC4A0>, <__main__.Event object at 0x00000177D92AAED0>]
# New path ['Knooppunt Empel', 'Knooppunt Deil', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 18.778155326112394 truck time:19.096478595780138
# [<__main__.Event object at 0x00000177D97DFEF0>, <__main__.Event object at 0x00000177D91E6510>]
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.780322173553003
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.833860865877753
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.840214649327876
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.90303989469328
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.92650227359493
# Accident already solved 18.998420198109535
# Truck 0 Now going from Knooppunt Deil to Knooppunt Gorinchem at time 19.096478595780138
#
# Truck 0 reaching Knooppunt Gorinchem at time 19.288131168590223
#
# On its way home
# Truck Truck 1 returned to base at time 19.120845814485378
# Trucks available after return: 1
#
# Tow truck back 19.120845814485378 truck time:19.120845814485378
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.120879873877225
# Accident already solved 19.17020372721908
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.200267505177525
# Truck Truck 0 returned to base at time 19.288131168590223
# Trucks available after return: 2
#
# Tow truck back 19.288131168590223 truck time:19.288131168590223
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 1', 'Truck 0']
#
# sending truck Truck 0 to Knooppunt Gouwe at time 19.889618958148876
#
# location 83.59296135337182% from Knooppunt Gouwe to Knooppunt Oudenrijn
# Incident at 19510.597179876982 from Knooppunt Gouwe, total_length = 23340.0
# Reaching Knooppunt Gouwe at 20.338714414713778
# Reaching incident at 20.548381222158618 incident should be solved atmost 20.83702840177319
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Ridderkerk at time 19.889618958148876
#
# Truck 0 reaching Knooppunt Ridderkerk at time 20.114437563638557
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gouwe->Knooppunt Oudenrijn', 'highway': 'motorway_link', 'length': 23340.0, 'lanes': 5, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000177D9727C20>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Ridderkerk at 20.114437563638557h, <class '__main__.Event'>
# Tow truck on its way 19.889618958148876
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.936938290451803
# Truck 0 Now going from Knooppunt Ridderkerk to Knooppunt Terbregseplein at time 20.114437563638557
#
# Truck 0 reaching Knooppunt Terbregseplein at time 20.143440341423457
#
# Truck 0 Now going from Knooppunt Terbregseplein to Knooppunt Gouwe at time 20.143440341423457
#
# Truck 0 reaching Knooppunt Gouwe at time 20.272586082925454
#
# New path ['Knooppunt Oudenrijn', 'Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Tow truck solved accident 20.272586082925454 truck time:20.63355523620619
# [<__main__.Event object at 0x00000177D97DE570>, <__main__.Event object at 0x00000177D97DF170>]
# Truck 0 Now going from Knooppunt Everdingen to Knooppunt Gorinchem at time 20.63355523620619
#
# Truck 0 reaching Knooppunt Gorinchem at time 20.854125725705007
#
# On its way home
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 1']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  20.71171096881054
# Accident already solved 20.83702840177319
# Truck Truck 0 returned to base at time 20.854125725705007
# Trucks available after return: 2
#
# Tow truck back 20.854125725705007 truck time:20.854125725705007
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 t = 0 #current time
#       2 while t < 24.0:
# ----> 3     event = fes.next()
#       4     t = event.time
#       6     #Car joins network
#
# Cell In[4], line 9, in FES.next(self)
#       8 def next(self):
# ----> 9     return heapq.heappop(self.events)
#
# IndexError: index out of range

# %%
Graph.nodes[('1410566272', '8432860337')[0]]
# Out:
# {'x': 4.6618705,
#  'y': 52.024019,
#  'highway': 'motorway_junction',
#  'name': 'Knooppunt Gouwe'}

# %%
#Checking if cars make it to destionation
for i in range(0, len(LIST_CARS)):
    car_i = LIST_CARS[i]
    # if car_i.progress != len(car_i.path) - 1:
    #     print(f'oh oh {LIST_CARS[i].time}')
    if car_i.path[car_i.progress] != car_i.destination:
        print(f'oh oh {LIST_CARS[i].time}')

# %%
#Proof that updating the car event also updates the one in the list
car_debug = Car(0)
list_debug = [car_debug.next_event]
print(list_debug[0].time)
car_debug.enter_queue(1)
car_debug.exit_queue(2)
print(list_debug[0].time)
# Out:
# 0.06544782683057422
# 1.0654478268305743
