# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import networkx as nx
import random
import heapq
import collections
from collections import deque

# %% [markdown]
# ### All the simulation uses hours and kilometers

# %%
ARRIVAL_RATE = np.array([314.2, 162.4, 138.6, 148.8, 273.2, 1118.8, 2773.8, 4036.2, 4237.4, 3277.0, 2843.0, 2876.4, 3143.0, 3277.8, 3546.2, 4335.0, 4945.4, 4525.8, 2847.8, 1828.0, 1378.4, 1271.2, 1171.2, 767.6])
INCIDENT_RATE = np.array([0.1935483870967742, 0.25806451612903225, 0.2903225806451613, 0.1935483870967742, 0.06451612903225806, 0.967741935483871, 32.16129032258065, 131.03225806451613, 157.2258064516129, 48.32258064516129, 8.451612903225806, 6.258064516129032, 8.161290322580646, 10.290322580645162, 19.0, 65.7741935483871, 157.41935483870967, 163.3548387096774, 36.54838709677419, 3.7096774193548385, 1.2258064516129032, 0.8709677419354839, 0.5806451612903226, 0.41935483870967744])
INCIDENT_DURATION_PARAMS = (1.2294425495153518, 0.09878316410683122, 5.082687545787541)
# INCIDENT_DURATION_PARAMS = ()

incident_duration_dist = stats.lognorm(*INCIDENT_DURATION_PARAMS)

MEAN_ACCIDENT_DURATION = 1

# %%
#Sampling arrival times of cars to network
def lambdat(lambda_t, t : np.array):
    lambdat = []
    for time in t:
        lambdat.append(lambda_t[int(np.floor(time))])
    return lambdat

def arrival_times(lam): #Taken from lecture notes
    max_T = 24
    arrival_times = collections.deque()
    exp_dist = stats.expon(scale = 1/lam)
    t = exp_dist.rvs()
    while t < max_T:
        arrival_times.append(t)
        t += exp_dist.rvs()
    
    return np.asarray(arrival_times)

# %%
class FES:
    def __init__(self):
        self.events = []

    def add(self, event):
        heapq.heappush(self.events, event)
    
    def next(self):
        return heapq.heappop(self.events)
    
    def isEmpty(self):
        return len(self.events) == 0
    
    def __repr__(self):
        string = ''
        sorted_events = sorted(self.events)
        for event in sorted_events:
            string += f'{event}\n'
        return string

# %%
class Queue:
    def __init__(self, road):
        self.road = road
        self.cars = []

    def add(self, car, time):
        heapq.heappush(self.cars, car)
        car.enter_queue(time)

    def add_list(self, list, time):
        for car in list:
            heapq.heappush(self.cars, car)
            car.enter_queue(time)   

    def next(self):
        return heapq.heappop(self.cars)
    
    def first(self):
        return heapq.nsmallest(1, self.cars)
    
    def isEmpty(self):
        return len(self.cars) == 0
    
    def __repr__(self):
        string = ''
        sorted_cars = sorted(self.cars)
        for car in sorted_cars:
            string += f'{car}\n'
        return string

# %%
class Event:
    TYPE = ['New car', 'Car departure', 'Accident', 'Accident end', 'left queue']
    def __init__(self, typ:int, time, car = None, road = None, duration = None):
        #types:
            #0 : Arrival of car to the network
            #1 : Car leaves current road and goes on to the next
            #2 : Accident in road
            #3 : End of accident
            #4 : Departure of car from queue of accident
        self.type = typ
        self.time = time
        self.road = road
        #Only for type 2 events bc needed for tow trucks
        self.duration = duration

        if typ == 0:
            car = Car(time_entrance = time)
    
        self.car = car
        
    def __str__(self):
        if self.type == 0:
            return f'{self.TYPE[self.type]} from {self.car.origin} to {self.car.destination} at {self.time}'
        if self.type == 1:
            return f'{self.TYPE[self.type]} of {self.car} at {self.time}h'
        if self.type == 2:
            return f'{self.TYPE[self.type]} at {self.road} at {self.time}h'
        if self.type == 3:
            return f'{self.TYPE[self.type]} at {self.road} at {self.time}h'
        if self.type == 4:
            return f'{self.car} {self.TYPE[self.type]} at {self.road} at {self.time}h'

    def __lt__(self, other):
        return self.time < other.time
    
    def new_time(self, new_time):
        self.time = new_time

# %%
class Car:
    VELOCITIES = [100, 80]
    VELOCITIES_P = [0.9, 0.1]
    def __init__(self, time_entrance, origin = None, destination = None):
        #Origin and destination
        origin, destination = np.random.choice(JUNCTIONS, 2, replace = False)
        
        self.origin = origin
        self.destination = destination

        #path to follow
        self.path = nx.shortest_path(Graph, self.origin, self.destination, weight = 'length')

        #Velocity
        self.velocity = np.random.choice(self.VELOCITIES, p=self.VELOCITIES_P)

        #Variable to keep track how far into the path we are (to simplify scheduling events)
        #Int between 0 and len(path) - 1 that indicates in which edge we are, starting at 0
        #Essentially, how many edges has it travelled so far
        self.progress = 0
        
        #Give it nav with 10% chance
        self.has_nav = np.random.choice([True, False], p=[0.1,0.9])
        self.changed_route = []

        #Time entrance
        self.time = time_entrance

        #Schedule next event and store it as attribute
        self.next_event = self.schedule_event_exit()


    def __str__(self):
        return f'Vehicle travelling from {self.origin} to {self.destination} at {self.velocity} km/h, atm at {self.path[self.progress]}'
    

    def custom_weight(self,u,v,data):
        """
        :param u: std for accepting function as weight, node 1
        :param v:  std for accepting function as weight, node 2
        :param data: std for accepting function as weight, edge
        :return: time_to_travel + delay
        """
        length = data['length']
        time_to_travel = (length / (self.velocity /3.6)) / 3600 #Mean of normal dist
        if Graph.edges[(u,v)]['accident']:   
            delay = MEAN_ACCIDENT_DURATION
        else:
            delay = 0
        return time_to_travel + delay
    
    def calc_time_to_travel(self,length):
        """
        :param length: edge length
        :return: returns time to traverse length based on normal speed
        """
        mean = length / (self.velocity /3.6) #seconds
        std = mean / 20
        time_to_travel = np.random.normal(loc = mean, scale = std) / 3600 #back to hours
        return time_to_travel

    def schedule_event_exit(self):
        #Remove car from list of cars in previous edge
        if self.progress > 0:
            #Edges can be expressed in two directions, account for it
            edge = (self.path[self.progress - 1], self.path[self.progress])
            # if edge in DIC_EDGES.keys():
            #     DIC_EDGES[edge].remove(self)
            # else:
            #     DIC_EDGES[edge[::-1]].remove(self)
            DIC_EDGES[edge].remove(self)


        if self.progress < len(self.path) - 1:
            # Get the current and next node on the original path
            current_node = self.path[self.progress]
            next_node = self.path[self.progress + 1]
            edge = Graph.edges[(current_node, next_node)]

            # Check for accident on the current edge and if nav is enabled
            # No need to check for accident, just check if navigation (there may be accidents later that makes us recompute)
            if self.has_nav:
                # print("Updating path")
                new_path = nx.shortest_path(Graph, current_node, self.destination, weight=self.custom_weight)

                if new_path != self.path[self.progress:]:
                    print("Found a quicker route")
                    # print(f"Prev path = {[Graph.nodes[node]['name'] for node in self.path]}")
                    # print(f"New path = {[Graph.nodes[node]['name'] for node in new_path]}")

                    #I commented this out bc append is not efficient
                    # self.changed_route.append((self.path, new_path))

                    # Preserve the already traversed portion
                    prefix = self.path[:self.progress]

                    updated_path = prefix + new_path
                    self.path = updated_path
                    # print(f"Updated path: {[Graph.nodes[node]['name'] for node in self.path]}")

                    # Update next_node based on the new path
                    next_node = self.path[self.progress + 1]
                    edge = Graph.edges[(current_node, next_node)]
                    length = edge['length']
                    # Sample travel time along the new edge (including accident delay)
                    
                    #I think no need to add accident duration bc i account for this in my code alr and a accident can happen before scheduling this
                    # time_to_travel = self.calc_time_to_travel(length) + edge['accident_duration']
                    time_to_travel = self.calc_time_to_travel(length)
                else:
                    # No change in path (fallback scenario)
                    length = edge['length']
                    time_to_travel = self.calc_time_to_travel(length)
            else:
                # Normal travel (no accident on the edge)
                length = edge['length']
                time_to_travel = self.calc_time_to_travel(length)

            new_time = self.time + time_to_travel
            # Schedule next event and update car's progress and time
            self.next_event = Event(1, new_time, car=self)
            self.increase_progress()
            self.increase_time(new_time)

            #Add car to list of cars in the new edge
            edge = (self.path[self.progress - 1], self.path[self.progress])
            # if edge in DIC_EDGES.keys():
            #     DIC_EDGES[edge].append(self)
            # else:
            #     DIC_EDGES[edge[::-1]].append(self)
            DIC_EDGES[edge].append(self)

            return self.next_event


    # def schedule_event_exit(self):

    #     #Remove car from list of cars in previous edge
    #     if self.progress > 0:
    #         #Edges can be expressed in two directions, account for it
    #         edge = (self.path[self.progress - 1], self.path[self.progress])
    #         # if edge in DIC_EDGES.keys():
    #         #     DIC_EDGES[edge].remove(self)
    #         # else:
    #         #     DIC_EDGES[edge[::-1]].remove(self)
    #         DIC_EDGES[edge].remove(self)


    #     if  self.progress < len(self.path) - 1: 
    #         #find next edge to travel through and its length
    #         edge = Graph.edges[(self.path[self.progress], self.path[self.progress + 1])]
    #         length = edge['length']

    #         #Sample travel time of edge
    #         mean = length / (self.velocity /3.6) #seconds
    #         std = mean / 20
    #         time_to_travel = np.random.normal(loc = mean, scale = std) / 3600 #back to hours

    #         new_time = self.time + time_to_travel

    #         #Store event and increase progress
    #         self.next_event = Event(1 , new_time, car=self)
    #         self.increase_progress()
    #         self.increase_time(new_time)

    #         #Add car to list of cars in the new edge
    #         edge = (self.path[self.progress - 1], self.path[self.progress])
    #         # if edge in DIC_EDGES.keys():
    #         #     DIC_EDGES[edge].append(self)
    #         # else:
    #         #     DIC_EDGES[edge[::-1]].append(self)
    #         DIC_EDGES[edge].append(self)

    #         return self.next_event
        
    #     # if self.progress == len(self.path) - 1:
    #     #     print('Car has reached its destination')
    #     #     self.travel_time = self.next_event.time
    
    def increase_progress(self):
        self.progress += 1

    def increase_time(self, new_time):
        self.time = new_time

    def __lt__(self, other):
        return self.time < other.time
    
    def enter_queue(self, time):
        #store time at which the car entered the queue
        self.time_enter = time

    def exit_queue(self, time_exit):
        #Update time of car when it left the queue
        self.time += time_exit - self.time_enter

        #Update time of event leaving road
        self.next_event.new_time(self.time)

# %%
class TowTruck:
    def __init__(self, origin, name=f"Truck {random.randint(0,100)}"):
        self.origin = origin
        self.isHome = True
        self.velocity = 80
        self.progress = 0
        self.time = 0
        self.going_home = False
        self.name = name
        self.next_event = None
    def __str__(self):
        at = self.path[self.progress]
        return f"Tow Truck travelling from {Graph.nodes[self.origin]['name']} to {Graph.edges[self.destination_road]} at {self.velocity} km/h, atm at {Graph.nodes[at]['name']}"

    def calc_time_to_travel(self,length):
        """
        :param length: edge length
        :return: returns time to traverse length based on normal speed
        """
        mean = length / (self.velocity /3.6) #seconds
        std = mean / 20
        time_to_travel = np.random.normal(loc = mean, scale = std) / 3600 #back to hours
        return time_to_travel

    def new_destination(self, destination_road, destination, current_time, distance_from_junction):
        if self.isHome:
            #Lets make destination = first item in destination road
            self.destination_road = destination_road
            self.destination = destination
            self.add_d = distance_from_junction
            self.path = nx.shortest_path(Graph, self.origin, self.destination, weight = 'length')
            self.isHome = False
            self.going_home = False
            self.time = current_time
            new_event = self.schedule_event_exit()
            
            return new_event
        else:
            print("Not able to set new destination, vehicle still on the road.")

    def schedule_event_exit(self):
        #Car is travelling and did not reach destination yet

        if  self.progress < len(self.path) - 1:
            # Can go on emergency lane so doesn't care for traffic jam
            current_node = self.path[self.progress]
            next_node = self.path[self.progress + 1]
            print(f"{self.name} Now going from {Graph.nodes[current_node]['name']} to {Graph.nodes[next_node]['name']} at time {self.time}\n")

            length = Graph.edges[(current_node,next_node)]['length']
            time_to_travel = self.calc_time_to_travel(length)

            new_time = self.time + time_to_travel
            print(f"{self.name} reaching {Graph.nodes[next_node]['name']} at time {new_time}\n")
            #Store event and increase progress
            self.next_event = Event(1 , new_time, car=self)
            self.increase_progress()
            self.increase_time(new_time)
            
            if self.going_home:
                print('On its way home')

            return self.next_event

        # Car reached destination, and is not going home
        elif (not(self.going_home)) and (self.progress == len(self.path) - 1):
            if self.origin == self.destination:
                print("TRIGGERED GORINCHEM ISSUE")
                self.progress =0
                # reached destination, Drive additional length to incident:
                self.time +=  self.calc_time_to_travel(self.add_d)
                print(f"Increased time {self.name} time to {self.time}")
                solving_event = Event(3, self.time, road = self.destination_road)
                print(f" {self.name} Solved event time {self.time}")
                # Calculate how long it takes to get to the other side of the road, i.e. next junction
                tot_road_length = nx.path_weight(Graph, self.destination_road,weight='length')
                # 'Drive' to other side
                self.time += self.calc_time_to_travel(tot_road_length-self.add_d)
                print(f" Arrived at opposite side of the road {self.time}")
                # Calculate new path from other side of the road
                self.path = [self.destination_road[1],self.destination_road[0]]
                print(f" Path to get back:{Graph.nodes[self.destination_road[1]]['name']} -> {Graph.nodes[self.destination_road[0]]['name']} {self.time}")
                length = Graph.edges[tuple(self.path)]['length']
                time_to_travel = self.calc_time_to_travel(length)
                new_time = self.time + time_to_travel
                print(f" Arrived back at origin base {new_time}")
                self.progress = len(self.path)-1
                self.increase_time(new_time)
                print(f" updated time to {self.time}")
                self.isHome = True
                self.going_home = False
                print(f"Now sending event back to event handler")
                return ['Truck back', solving_event]


            # reached destination, Drive additional length to incident:
            self.increase_time( self.calc_time_to_travel(self.add_d))
            solving_event = Event(3, self.time, road = self.destination_road)
            # Calculate how long it takes to get to the other side of the road, i.e. next junction
            tot_road_length = nx.path_weight(Graph, self.destination_road,weight='length')
            # 'Drive' to other side
            self.increase_time (self.calc_time_to_travel(tot_road_length-self.add_d))
            # Calculate new path from other side of the road

            self.path = nx.shortest_path(Graph, self.destination_road[1], self.origin, weight = 'length')

            # Reset progress
            print(f"New path {[Graph.nodes[nodes]['name'] for nodes in self.path]}")
            self.progress = 0

            # edge = Graph.edges[(self.destination, self.path[1])]
            print('Heading home')
            if len(self.path) > 1:
                print("##### Flag 0 #####")
                length = Graph.edges[(self.destination_road[1], self.path[1])]['length']

                time_to_travel = self.calc_time_to_travel(length)
                new_time = self.time + time_to_travel

                self.increase_progress()
                self.increase_time(new_time)
                self.next_event = Event(1, new_time, car=self)
                self.going_home = True
                
                return [self.next_event, solving_event]
            else:
                #Never triggered, Alr at home
                print("##### Flag 1 #####")
                self.isHome = True
                self.going_home = False
                return ['Truck back', solving_event]
        # Car is going home, and reached destination, thus reached home
        elif (self.going_home) and (self.progress == len(self.path) - 1):
            self.isHome = True
            self.going_home = False
            return 'Truck back'

    def increase_progress(self):
        self.progress += 1

    def increase_time(self, new_time):
        self.time = new_time

# %%
class IncidentSolvers:
    def __init__(self,K_trucks, origin ='2752332143'):
        self.origin = origin
        self.K_trucks = K_trucks
        self.trucks = []
        self.available = deque()
        self.unavailable = deque()
        for i in range(K_trucks):
            truck = TowTruck(origin=origin)
            truck.name = f"Truck {i}"

            self.trucks.append(truck)
            self.available.append(truck)

    def truck_returned(self, truck):
        if truck in self.unavailable:
            self.unavailable.remove(truck)

        self.available.append(truck)
        truck.progress = 0
        truck.isHome = True
        truck.going_home = False
        truck.path = None
        print(f"Truck {truck.name} returned to base at time {truck.time}")
        print("Trucks available after return:",len(self.available),'\n')


    def send_truck(self, destination_road, incident_duration, current_time,location):
        print(f"trying to send a truck, \n \
        amount trucks available: {len(self.available)} \n trucks available: {[truck.name for truck in self.available]}\n")
        if len(self.available) > 0:
            truck = self.available.pop()
            # Check if truck can reach in time
            destination = destination_road[0]
            path = nx.shortest_path(Graph, self.origin, destination, weight='length')
            length = nx.path_weight(Graph, path,weight='length')
            length_additional = location * nx.path_weight(Graph, destination_road,weight='length')
            time_to_travel = truck.calc_time_to_travel(length + length_additional)


            if time_to_travel> incident_duration:
                print("Takes too long to reach incident location\n")
                self.available.append(truck)
                return
            else:
                # Send the truck to the incident.
                print(f"sending truck {truck.name} to {Graph.nodes[destination]['name']} at time {current_time}\n")
                print(f"location {location*100}% from {Graph.nodes[destination_road[0]]['name']} to {Graph.nodes[destination_road[1]]['name']} ")
                print(f"Incident at {length_additional} from {Graph.nodes[destination]['name']}, total_length = {nx.path_weight(Graph, destination_road,weight='length')}")
                print(f"Reaching {Graph.nodes[destination]['name']} at {current_time+ truck.calc_time_to_travel(length)} ")
                reaching_time = current_time + time_to_travel
                print(f"Reaching incident at {reaching_time} incident should be solved atmost {current_time + incident_duration}\n")
                event_truck = truck.new_destination(destination_road,destination, current_time, distance_from_junction=length_additional)
                self.unavailable.append(truck)
                return event_truck

        else:
            print('No trucks available sry')

# %%
Graph = nx.read_gml('./data/networkAssignment.gml')
Graph = Graph.to_directed()
JUNCTIONS = list(Graph.nodes)
DIC_EDGES = {}
#Dictionary that keeps track on when the last accident ends in a road before another one can take place
DIC_ACCIDENTS = {}
for edge in Graph.edges:
    DIC_EDGES[edge] = []
    DIC_ACCIDENTS[edge] = 0
    #Associate departure from queue distribution to each edge based on number of lanes
    rate = 0.2/(60 * Graph.edges[edge]['lanes'])
    Graph.edges[edge]['DepDist'] = stats.expon(scale = rate)

    Graph.edges[edge]['accident'] = False
    Graph.edges[edge]['queue'] = False
    # Graph.edges[edge]['accident_duration'] = 0

# %%
#Using a thining approach to get arrival times
max_lambda = np.max(ARRIVAL_RATE) + 1
all_arrivals = arrival_times(max_lambda)

uniform_dist = stats.uniform(0,1)
u_rvs = uniform_dist.rvs(len(all_arrivals))
accept_filter = u_rvs * max_lambda < lambdat(ARRIVAL_RATE, all_arrivals)

accepted_arrivals = all_arrivals[accept_filter]

# %%
#Using a thining approach to get accident times
max_lambda = np.max(INCIDENT_RATE) + 1
all_accidents = arrival_times(max_lambda)

uniform_dist = stats.uniform(0,1)
u_rvs = uniform_dist.rvs(len(all_accidents))
accept_filter = u_rvs * max_lambda < lambdat(INCIDENT_RATE, all_accidents)

accepted_accidents = all_accidents[accept_filter]

# %%
incident_solvers = IncidentSolvers(2)

# %%
#Simulation (can be turned into an object later)
LIST_CARS = []
fes = FES()
# for arrival in accepted_arrivals:
#     #Two events associated with each arrival
#     arrival_event = Event(0, arrival)
#     fes.add(arrival_event)

for accident in accepted_accidents:
    affected_road = list(Graph.edges)[np.random.choice(len(Graph.edges))]
    if DIC_ACCIDENTS[affected_road] < accident:
        duration = incident_duration_dist.rvs()/60
        time_end = accident + duration
        accident_event = Event(2, accident, road=affected_road, duration=duration)
        end_accident = Event(3, time_end, road=affected_road)

        fes.add(accident_event)
        fes.add(end_accident)
        DIC_ACCIDENTS[affected_road] = time_end

#Queue for accidents setup
Queues = {}
for edge in DIC_EDGES.keys():
    Queues[edge] = Queue(edge)

# %%
# road = list(DIC_EDGES.keys())[0]
# accident = Event(2, 0.5, road=road)
# end_accident = Event(3, 0.6, road =road)
# fes.add(accident)
# fes.add(end_accident)
# road = road[::-1]
# accident = Event(2, 0.5, road=road)
# end_accident = Event(3, 0.6, road =road)
# fes.add(accident)
# fes.add(end_accident)

# %%
t = 0 #current time
while t < 24.0:
    event = fes.next()
    t = event.time

    #Car joins network
    if event.type == 0:
        car_travel_event = event.car.next_event
        fes.add(car_travel_event)
        LIST_CARS.append(event.car)

    #Car leaves road
    if event.type == 1:
        next_travel_event_car = event.car.schedule_event_exit()
        if type(next_travel_event_car) == Event: #If the car has arrived to its destination it wont return an event object
            fes.add(next_travel_event_car)

        #when a tow truck arrives to the accident it wants to solve, it will return two events
        if type(next_travel_event_car) == list:
            #Event for fixing the accident
            fes.add(next_travel_event_car[1])
            print(f'Tow truck solved accident {t}')

            print(next_travel_event_car)
            #Event for heading back
            if type(next_travel_event_car[0]) == Event:
                fes.add(next_travel_event_car[0])
            #it may alr be at home
            elif next_travel_event_car[0] == 'Truck back':
                incident_solvers.truck_returned(event.car)
                print(f'Tow truck back {t}')

        if next_travel_event_car == 'Truck back':
            incident_solvers.truck_returned(event.car)
            print(f'Tow truck back {t}')
         # else:
            # print(event.car)

    #Start accident
    if event.type == 2:
        road = event.road
        #choose random cars affected:
            #List comprehension is inefficient af here
            # cars_not_in_queue = [car for car in DIC_EDGES[road] if car not in Queues[road].cars]
        cars_not_in_queue = list(set(DIC_EDGES[road]) - set(Queues[road].cars))
        if len(cars_not_in_queue) != 0:


            amount_cars_affected = np.random.randint(len(cars_not_in_queue))
            cars_affected = np.random.choice(cars_not_in_queue, amount_cars_affected, replace=False)


            #####Consider sorting list of cars before chooisng which ones are affected


            Queues[road].add_list(cars_affected, event.time)
        Graph.edges[road]['accident'] = True
        #Send tow truck
        # print("This road:",road)

        # Location on the road
        # Trying to keep it simple for debug purpose
        # Loc * Length / velocity will be the additional time it takes
        loc = stats.uniform(0, 1).rvs()

        first_event_truck = incident_solvers.send_truck(road, event.duration, event.time,location=loc)
        print(f'1330 {first_event_truck}, {type(first_event_truck)}')
        #If no trucks are available first_event_truck will be empty
        if type(first_event_truck) == Event:
            fes.add(first_event_truck)
            print(f'Tow truck on its way {t}')
        elif type(first_event_truck) == list:
            fes.add(first_event_truck[1])
            print(f'Tow truck on its way {t}')
        else:
            print(f'Tow trucks all busy  {t}')

    #End accident
    if event.type == 3:
        road = event.road
        #A tow truck may have ended he accident before so there could be two events for ending it, hence only do it if there is still an accident
        if Graph.edges[road]['accident']:
            #1 minute until first car leaves the queue 
            if not(Queues[road].isEmpty()) and not(Graph.edges[road]['queue']):
                # print(f'First event departure {Queues[road].isEmpty()}', road)
                first_departure_event = Event(4, event.time + 1/60, road=road)
                # print(first_departure_event)
                fes.add(first_departure_event)
                Graph.edges[road]['queue'] = True
            Graph.edges[road]['accident'] = False   
        # print(t)
        else:
            print(f'Accident already solved {t}')
    
    #Departure from road
    if event.type == 4:
        # print(event)
        road = event.road
        time = event.time
        #Remove car from queue
        # print(len(Queues[road].cars), event.road)
        car = Queues[road].next()

        #Modify time to arrival of next node in path
        car.exit_queue(time)

        if not(Queues[road].isEmpty()):
            #Next departure event
            next_event_time = time + Graph.edges[road]['DepDist'].rvs()
            
            next_event = Event(4, next_event_time, road=road)
            # print(next_event)
            fes.add(next_event)
        else:
            Graph.edges[road]['queue'] = False
# Out:
# trying to send a truck,
#          amount trucks available: 2
#  trucks available: ['Truck 0', 'Truck 1']
#
# sending truck Truck 1 to Knooppunt Gorinchem at time 2.4703700569123095
#
# location 55.7611834641373% from Knooppunt Gorinchem to Knooppunt Everdingen
# Incident at 9926.04826845108 from Knooppunt Gorinchem, total_length = 17801.0
# Reaching Knooppunt Gorinchem at 2.4703700569123095
# Reaching incident at 2.5922464648775088 incident should be solved atmost 2.593806491779275
#
# TRIGGERED GORINCHEM ISSUE
# Increased time Truck 1 time to 2.5962612469586874
#  Truck 1 Solved event time 2.5962612469586874
#  Arrived at opposite side of the road 2.68902036667534
#  Path to get back:Knooppunt Everdingen -> Knooppunt Gorinchem 2.68902036667534
#  Arrived back at origin base 2.9209676153660173
#  updated time to 2.9209676153660173
# Now sending event back to event handler
# 1330 ['Truck back', <__main__.Event object at 0x000001EC8F2D1490>], <class 'list'>
# Accident already solved 2.5962612469586874
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  5.496731024362584
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  5.61646398901525
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  5.70461251088246
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.020338953686837
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.031853569140194
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Zonzeel at time 6.062872098215987
#
# location 82.00728631217687% from Knooppunt Zonzeel to Knooppunt Princeville
# Incident at 5177.940057750848 from Knooppunt Zonzeel, total_length = 6314.0
# Reaching Knooppunt Zonzeel at 6.359484762751209
# Reaching incident at 6.441221634649048 incident should be solved atmost 6.498375982652114
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Hooipolder at time 6.062872098215987
#
# Truck 0 reaching Knooppunt Hooipolder at time 6.228541599426959
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Zonzeel->Knooppunt Princeville', 'highway': 'motorway_link', 'length': 6314.0, 'lanes': 4, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EC8F2C1070>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Hooipolder at 6.228541599426959h, <class '__main__.Event'>
# 1331 Added to fes
# Tow truck on its way 6.062872098215987
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.080900757303676
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.08566200767316
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.114090617507374
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.130900137293223
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.1637785878134785
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.200063753635507
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.218724611557894
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.22009441199561
# Truck 0 Now going from Knooppunt Hooipolder to Knooppunt Zonzeel at time 6.228541599426959
#
# Truck 0 reaching Knooppunt Zonzeel at time 6.358652662854708
#
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.231462769563997
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.316550402874128
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.327391426521124
# New path ['Knooppunt Princeville', 'Knooppunt Zonzeel', 'Knooppunt Hooipolder', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Truck 0 Now going from Knooppunt Zonzeel to Knooppunt Hooipolder at time 0.10012285999619128
#
# Truck 0 reaching Knooppunt Hooipolder at time 0.22545991497088522
#
# On its way home
# Truck 0 Now going from Knooppunt Hooipolder to Knooppunt Gorinchem at time 0.22545991497088522
#
# Truck 0 reaching Knooppunt Gorinchem at time 0.3964688764156158
#
# On its way home
# Truck Truck 0 returned to base at time 0.3964688764156158
# Trucks available after return: 1
#
# Tow truck back 0.3964688764156158
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.3596279813062635
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.374083064420313
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.453208875310064
# Accident already solved 6.498375982652114
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.533386858814297
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.542734288176138
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.564166795826942
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.574666423373044
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.609814340942183
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.6168891847738776
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.69562710864703
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.718709429745597
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.732658234907789
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Everdingen at time 6.750439957111602
#
# location 59.65522783184583% from Knooppunt Everdingen to Knooppunt Oudenrijn
# Incident at 3235.6995575993174 from Knooppunt Everdingen, total_length = 5424.0
# Reaching Knooppunt Everdingen at 6.969477880074882
# Reaching incident at 6.989958028791482 incident should be solved atmost 7.035097294337688
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Everdingen at time 6.750439957111602
#
# Truck 0 reaching Knooppunt Everdingen at time 6.980399808481341
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Everdingen->Knooppunt Oudenrijn', 'highway': 'motorway_link', 'length': 5424.0, 'lanes': 5, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EC8F176570>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Everdingen at 6.980399808481341h, <class '__main__.Event'>
# 1331 Added to fes
# Tow truck on its way 6.750439957111602
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.763815914171227
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.782602310109216
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.793542082459001
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.801252446725943
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.884589078149913
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.901392012924828
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.907160192603964
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.943107199793187
# New path ['Knooppunt Oudenrijn', 'Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Truck 0 Now going from Knooppunt Everdingen to Knooppunt Gorinchem at time 0.09863162422499572
#
# Truck 0 reaching Knooppunt Gorinchem at time 0.31840759351787673
#
# On its way home
# Truck Truck 0 returned to base at time 0.31840759351787673
# Trucks available after return: 1
#
# Tow truck back 0.31840759351787673
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.988800370862071
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  6.993070751791346
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.0118444208621495
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.015374196139517
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.0242532904935
# Accident already solved 7.035097294337688
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.039701078157396
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.039802501966754
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.0548113971609085
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.0563813670506965
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Ridderkerk at time 7.076078467909443
#
# location 40.72726093274815% from Knooppunt Ridderkerk to Knooppunt Terbregseplein
# Incident at 988.0433502284702 from Knooppunt Ridderkerk, total_length = 2426.0
# Reaching Knooppunt Ridderkerk at 7.32028393081203
# Reaching incident at 7.336928764415774 incident should be solved atmost 7.372778331525639
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Ridderkerk at time 7.076078467909443
#
# Truck 0 reaching Knooppunt Ridderkerk at time 7.332789351704644
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Terbregseplein->Knooppunt Ridderkerk', 'highway': 'motorway_link', 'length': 2426.0, 'lanes': 3, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EC8F1D73E0>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Ridderkerk at 7.332789351704644h, <class '__main__.Event'>
# 1331 Added to fes
# Tow truck on its way 7.076078467909443
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.078664770608917
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.079681462762797
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.089586878623115
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.0911509794098695
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.097869304285872
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.112828138886295
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.129419264798446
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.165488857371704
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.16928406150246
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.194520831085417
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.197790739091474
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.209625889995334
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.235297475678059
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.2489913795883245
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.255887441935127
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.277994251774042
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.281118758210832
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.2820717112073865
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.2826591093463
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.285996008791203
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.28839262725361
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.290281541628039
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.294522607132746
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.296891597455354
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.317691867424075
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.331532334341678
# New path ['Knooppunt Terbregseplein', 'Knooppunt Ridderkerk', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Truck 0 Now going from Knooppunt Ridderkerk to Knooppunt Gorinchem at time 0.05161295447581229
#
# Truck 0 reaching Knooppunt Gorinchem at time 0.3104952746321774
#
# On its way home
# Truck Truck 0 returned to base at time 0.3104952746321774
# Trucks available after return: 1
#
# Tow truck back 0.3104952746321774
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.3494557601182615
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.353599957434748
# Accident already solved 7.372778331525639
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.373333171615733
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.392177630135321
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.39799749798264
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.4048170348064595
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.42689643180438
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.42723978972002
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.42840435423697
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.434167624073995
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.437475462599714
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.4438237623065575
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Ypenburg at time 7.461414876001551
#
# location 25.604990324621912% from Knooppunt Ypenburg to Knooppunt Gouwe
# Incident at 4168.2363749452015 from Knooppunt Ypenburg, total_length = 16279.0
# Reaching Knooppunt Ypenburg at 7.880290787129531
# Reaching incident at 7.984177786956984 incident should be solved atmost 8.556363519829505
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Ridderkerk at time 7.461414876001551
#
# Truck 0 reaching Knooppunt Ridderkerk at time 7.713994588696734
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gouwe->Knooppunt Ypenburg', 'highway': 'motorway_link', 'length': 16279.0, 'lanes': 4, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EC8F1D5580>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Ridderkerk at 7.713994588696734h, <class '__main__.Event'>
# 1331 Added to fes
# Tow truck on its way 7.461414876001551
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.462121887266037
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.472915749830097
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.476743438706154
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.485274708470322
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.489819071422821
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.518672763992024
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.519289159402894
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.52986022853581
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.5387932195414304
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.539439086746209
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.539895574606773
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.549198277569433
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.554976640259873
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.567534225419636
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.571399253357002
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.5761563637186216
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.576969338607167
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.588689059753975
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.610950379655551
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.612451696478277
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.630957610215265
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.6323529913311425
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.651561835419044
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.660643602022002
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.664068756908655
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.679227118688073
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.697736164771169
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.697926689355088
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.698449297528224
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.702522819919486
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.704130527165724
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.7077348070199
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.710325385160725
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.712077032619987
# Truck 0 Now going from Knooppunt Ridderkerk to Knooppunt Terbregseplein at time 7.713994588696734
#
# Truck 0 reaching Knooppunt Terbregseplein at time 7.745425867674833
#
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.7187444233498095
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.7381963534163
# Truck 0 Now going from Knooppunt Terbregseplein to Knooppunt Ypenburg at time 7.745425867674833
#
# Truck 0 reaching Knooppunt Ypenburg at time 7.89797664668759
#
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.756068631630531
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.785191860051394
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.799329489721535
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.800715459908664
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.804282606251278
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.812253505686329
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.814002574324655
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.827934287213601
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.832902746644262
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.864970432827184
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.868334673501847
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.8716972107560865
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.8765050205262614
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.886150221448754
# New path ['Knooppunt Gouwe', 'Knooppunt Terbregseplein', 'Knooppunt Ridderkerk', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Truck 0 Now going from Knooppunt Terbregseplein to Knooppunt Ridderkerk at time 0.2863914364914453
#
# Truck 0 reaching Knooppunt Ridderkerk at time 0.3188394232568939
#
# On its way home
# Truck 0 Now going from Knooppunt Ridderkerk to Knooppunt Gorinchem at time 0.3188394232568939
#
# Truck 0 reaching Knooppunt Gorinchem at time 0.5467450375155604
#
# On its way home
# Truck Truck 0 returned to base at time 0.5467450375155604
# Trucks available after return: 1
#
# Tow truck back 0.5467450375155604
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Hooipolder at time 7.89988468322606
#
# location 88.14765521328582% from Knooppunt Hooipolder to Knooppunt Gorinchem
# Incident at 11533.239208106315 from Knooppunt Hooipolder, total_length = 13084.0
# Reaching Knooppunt Hooipolder at 8.063182457849528
# Reaching incident at 8.2131367503154 incident should be solved atmost 8.317091942735502
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Hooipolder at time 7.89988468322606
#
# Truck 0 reaching Knooppunt Hooipolder at time 8.069421989034854
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gorinchem->Knooppunt Hooipolder', 'highway': 'motorway_link', 'length': 13084.0, 'lanes': 2, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EC8F176180>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Hooipolder at 8.069421989034854h, <class '__main__.Event'>
# 1331 Added to fes
# Tow truck on its way 7.89988468322606
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.927743361179238
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.953405625244022
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.967091200200807
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.978221844303321
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  7.99402173779332
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.008006023417884
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.008327486679281
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.01215786428241
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.013813431029593
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.022785139521142
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.04107691542571
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.066805435316542
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.06714243699888
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.067928633029156
# New path ['Knooppunt Gorinchem']
# Heading home
# ##### Flag 1 #####
# Truck Truck 0 returned to base at time 0.018798151227422667
# Trucks available after return: 1
#
# Tow truck back 8.069421989034854
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.082130681240566
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.084658091560192
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.098458004028933
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.114022760647638
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.114401885564611
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.130605878416738
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# sending truck Truck 0 to Knooppunt Gouwe at time 8.136539284186627
#
# location 35.54125702131735% from Knooppunt Gouwe to Knooppunt Oudenrijn
# Incident at 8295.32938877547 from Knooppunt Gouwe, total_length = 23340.0
# Reaching Knooppunt Gouwe at 8.557363318111014
# Reaching incident at 8.677087357932423 incident should be solved atmost 10.833122477692497
#
# Truck 0 Now going from Knooppunt Gorinchem to Knooppunt Ridderkerk at time 8.136539284186627
#
# Truck 0 reaching Knooppunt Ridderkerk at time 8.37625774067686
#
# 1330 Car departure of Tow Truck travelling from Knooppunt Gorinchem to {'name': 'Knooppunt Gouwe->Knooppunt Oudenrijn', 'highway': 'motorway_link', 'length': 23340.0, 'lanes': 5, 'DepDist': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001EC8F061BB0>, 'accident': True, 'queue': False} at 80 km/h, atm at Knooppunt Ridderkerk at 8.37625774067686h, <class '__main__.Event'>
# 1331 Added to fes
# Tow truck on its way 8.136539284186627
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.147771126028838
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.14855547576279
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.150283636302317
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.152146374982886
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.16205844266552
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.178916916626836
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.190630131900546
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.193337058792702
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.198034274177646
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.198299023502143
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.223374507376803
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.232125113869616
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.234765382586188
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.259367535215327
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.270968548902706
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.275539597618854
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.301335528434038
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.304891464428875
# Accident already solved 8.317091942735502
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.333508102798836
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.341695195195863
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.349836611302084
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.351600825834042
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.354049982661788
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.3541665257275
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.361760346762066
# Truck 0 Now going from Knooppunt Ridderkerk to Knooppunt Terbregseplein at time 8.37625774067686
#
# Truck 0 reaching Knooppunt Terbregseplein at time 8.40599569211432
#
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.379165822541022
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.3885097448023
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.393066629155904
# Truck 0 Now going from Knooppunt Terbregseplein to Knooppunt Gouwe at time 8.40599569211432
#
# Truck 0 reaching Knooppunt Gouwe at time 8.535597906615854
#
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.41398547462165
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.426806335646434
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.441387451173785
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.445887593404109
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.4561541493917
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.463987891915341
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.464454535766697
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.47271134331715
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.474992481898116
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.481267518633326
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.494384520871568
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.502455648477461
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.528155188085305
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.52912662355856
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.532166763734148
# New path ['Knooppunt Oudenrijn', 'Knooppunt Everdingen', 'Knooppunt Gorinchem']
# Heading home
# ##### Flag 0 #####
# Truck 0 Now going from Knooppunt Everdingen to Knooppunt Gorinchem at time 0.2555922983183508
#
# Truck 0 reaching Knooppunt Gorinchem at time 0.463921901048006
#
# On its way home
# Truck Truck 0 returned to base at time 0.463921901048006
# Trucks available after return: 1
#
# Tow truck back 0.463921901048006
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.540044025929078
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.543113093024116
# Accident already solved 8.556363519829505
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# Takes too long to reach incident location
#
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  8.571828082270638
# trying to send a truck,
#          amount trucks available: 1
#  trucks available: ['Truck 0']
#
# ...
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.495722747584118
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.51712525361503
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.54003243999974
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.541557519900316
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.541865348157717
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.558685216929835
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.559177439732977
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.563728124014634
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.57351012191855
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.591262099983254
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.605084335361212
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.605101705003396
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.62012429864835
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.63257730105353
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.645671853495266
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.658642850031285
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.665532518262836
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.670838608758093
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.671224911388425
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.67389117977436
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.68426092709321
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.706012236750244
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.70769275907995
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.719115083947745
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.723942556702443
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.72407262724391
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.767319888050682
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.773618072491306
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.77521007147115
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.790288595193847
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.79688150063463
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.7977219023009
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.81074379126704
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.812039922950333
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.820344186121034
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.82039148026587
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.83683303018742
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.837797352639395
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.84825601783818
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.8505654438823
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.86344784419629
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.89802758309624
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.898972779801525
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.90212885460265
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.903839645823794
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.912118189503072
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.93271195010022
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.938881559881523
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.952640411218407
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.980564809222827
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.98282048803305
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  17.994378349503624
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.003357823208948
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.027120404726745
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.033851172798553
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.040372205834835
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.15027931694926
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.210947212534155
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.231236892019034
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.279496217541272
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.29445725980046
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.331471350959877
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.3799530275174
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.470346432967727
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.50871282775587
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.521766417173833
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.56579229688002
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.567034963303357
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.597934441843464
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.607478387237837
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.63038893025281
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.688328216132298
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.75851092772076
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.782577158978153
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.793481681541685
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.84090412712042
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.885339412983384
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.88657887766231
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  18.910010503366298
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.045239685331364
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.104515047793267
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.65317019255983
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.780954070168743
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  19.910312506730442
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  20.25412693794839
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  20.379672972398517
# trying to send a truck,
#          amount trucks available: 0
#  trucks available: []
#
# No trucks available sry
# 1330 None, <class 'NoneType'>
# Tow trucks all busy  23.933098076859626
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[96], line 3
#       1 t = 0 #current time
#       2 while t < 24.0:
# ----> 3     event = fes.next()
#       4     t = event.time
#       6     #Car joins network
#
# Cell In[84], line 9, in FES.next(self)
#       8 def next(self):
# ----> 9     return heapq.heappop(self.events)
#
# IndexError: index out of range

# %%
Graph.nodes[('1410566272', '8432860337')[0]]
# Out:
# {'x': 4.6618705,
#  'y': 52.024019,
#  'highway': 'motorway_junction',
#  'name': 'Knooppunt Gouwe'}

# %%
#Checking if cars make it to destionation
for i in range(0, len(LIST_CARS)):
    car_i = LIST_CARS[i]
    # if car_i.progress != len(car_i.path) - 1:
    #     print(f'oh oh {LIST_CARS[i].time}')
    if car_i.path[car_i.progress] != car_i.destination:
        print(f'oh oh {LIST_CARS[i].time}')

# %%
#Proof that updating the car event also updates the one in the list
car_debug = Car(0)
list_debug = [car_debug.next_event]
print(list_debug[0].time)
car_debug.enter_queue(1)
car_debug.exit_queue(2)
print(list_debug[0].time)
# Out:
# 0.06544782683057422
# 1.0654478268305743
