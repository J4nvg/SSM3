# %%
import networkx as nx
assignmentGraph = nx.read_gml('./data/networkAssignment.gml')
assignmentGraph2 = assignmentGraph.copy()
for e in assignmentGraph2.edges:
    assignmentGraph2.edges[e]['accident'] = False
    # assignmentGraph2.edges[e]['accident_location'] =
